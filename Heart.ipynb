# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Load dataset
df = pd.read_csv('heart.csv')

# Preprocessing: Pisahkan fitur dan target
X = df.drop('target', axis=1).values
y = df['target'].values

# %%
# Normalisasi data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Convert ke tensor
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
# Definisikan model MLP
def create_mlp(input_size, hidden_layers, hidden_neurons, activation_function):
    layers = []
    # Input layer to first hidden layer
    layers.append(nn.Linear(input_size, hidden_neurons))

    # Menambah hidden layers
    for _ in range(hidden_layers - 1):
        layers.append(nn.Linear(hidden_neurons, hidden_neurons))

    # Pilih fungsi aktivasi
    if activation_function == 'linear':
        activation = nn.Identity()
    elif activation_function == 'Sigmoid':
        activation = nn.Sigmoid()
    elif activation_function == 'ReLU':
        activation = nn.ReLU()
    elif activation_function == 'Softmax':
        activation = nn.Softmax(dim=1)
    elif activation_function == 'Tanh':
        activation = nn.Tanh()

    # Output layer
    layers.append(nn.Linear(hidden_neurons, 2))  # Output 2 kelas (0 atau 1)

    # Gabungkan semua layers
    model = nn.Sequential(*layers)
    return model
# Fungsi untuk melatih dan mengevaluasi model
def train_and_evaluate(model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate):
    # DataLoader untuk batch training
    train_data = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

    # Optimizer (Adam) dan loss function (CrossEntropyLoss untuk klasifikasi)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    # Training loop
    model.train()  # Set model ke mode training
    for epoch in range(epochs):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()  # Reset gradient
            output = model(X_batch)  # Prediksi dengan model
            loss = criterion(output, y_batch)  # Hitung loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update parameter model

    # Evaluasi model setelah training
    model.eval()  # Set model ke mode evaluasi (tidak ada gradient update)
    with torch.no_grad():  # Matikan gradient untuk efisiensi
        # Training accuracy
        train_output = model(X_train_tensor)
        train_pred = torch.argmax(train_output, dim=1)  # Prediksi kelas dengan argmax
        train_accuracy = accuracy_score(y_train_tensor.numpy(), train_pred.numpy())  # Akurasi training
        train_loss = criterion(train_output, y_train_tensor).item()  # Hitung loss di data training

        # Test accuracy
        test_output = model(X_test_tensor)
        test_pred = torch.argmax(test_output, dim=1)
        test_accuracy = accuracy_score(y_test_tensor.numpy(), test_pred.numpy())  # Akurasi testing
        test_loss = criterion(test_output, y_test_tensor).item()  # Hitung loss di data testing

    return train_accuracy, train_loss, test_accuracy, test_loss  # Return hasil
# Daftar hyperparameter untuk eksperimen
hidden_layers_options = [1, 2, 3]  # Jumlah hidden layers
hidden_neurons_options = [8, 16, 32]  # Jumlah neuron di setiap hidden layer
activation_functions = ['linear', 'Sigmoid', 'ReLU', 'Softmax', 'Tanh']  # Fungsi aktivasi
epochs_options = [10, 25, 50, 100]  # Jumlah epochs
learning_rates = [0.1, 0.01, 0.001, 0.0001]  # Learning rates
batch_sizes = [64, 128, 256, 512]  # Ukuran batch

# Eksperimen dengan kombinasi semua hyperparameters
results = []  # Menyimpan hasil eksperimen
best_result = None
worst_result = None

for hidden_layers in hidden_layers_options:
    for hidden_neurons in hidden_neurons_options:
        for activation_function in activation_functions:
            for epochs in epochs_options:
                for learning_rate in learning_rates:
                    for batch_size in batch_sizes:
                        # Print konfigurasi yang sedang dijalankan
                        print(f"Training with {hidden_layers} hidden layers, {hidden_neurons} neurons, {activation_function} activation, "
                              f"{epochs} epochs, {learning_rate} learning rate, {batch_size} batch size")

                        # Buat model untuk setiap kombinasi hyperparameter
                        model = create_mlp(X_train_tensor.shape[1], hidden_layers, hidden_neurons, activation_function)

                        # Latih dan evaluasi model
                        train_acc, train_loss, test_acc, test_loss = train_and_evaluate(
                            model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate
                        )

                        # Simpan hasil eksperimen
                        results.append({
                            'Hidden Layers': hidden_layers,
                            'Hidden Neurons': hidden_neurons,
                            'Activation Function': activation_function,
                            'Epochs': epochs,
                            'Learning Rate': learning_rate,
                            'Batch Size': batch_size,
                            'Train Accuracy': train_acc,
                            'Train Loss': train_loss,
                            'Test Accuracy': test_acc,
                            'Test Loss': test_loss
                        })

                        # Print hasil akhir akurasi dan detail lainnya
                        print(f"Train Accuracy: {train_acc * 100:.2f}%")
                        print(f"Train Loss: {train_loss:.4f}")
                        print(f"Test Accuracy: {test_acc * 100:.2f}%")
                        print(f"Test Loss: {test_loss:.4f}\n")

                        # Update best and worst results
                        if best_result is None or test_acc > best_result['Test Accuracy']:
                            best_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                        if worst_result is None or test_acc < worst_result['Test Accuracy']:
                            worst_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Test Loss: 0.6032
#
# Training with 3 hidden layers, 8 neurons, Sigmoid activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 69.60%
# Train Loss: 0.6563
# Test Accuracy: 65.91%
# Test Loss: 0.6617
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 79.92%
# Train Loss: 2.3044
# Test Accuracy: 75.65%
# Test Loss: 3.0174
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3549
# Test Accuracy: 79.87%
# Test Loss: 0.4794
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3367
# Test Accuracy: 80.19%
# Test Loss: 0.4184
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3384
# Test Accuracy: 79.22%
# Test Loss: 0.4385
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3359
# Test Accuracy: 82.14%
# Test Loss: 0.4087
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3339
# Test Accuracy: 80.19%
# Test Loss: 0.4174
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 87.59%
# Train Loss: 0.3428
# Test Accuracy: 82.79%
# Test Loss: 0.3853
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3613
# Test Accuracy: 82.14%
# Test Loss: 0.4300
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 84.94%
# Train Loss: 0.3535
# Test Accuracy: 79.22%
# Test Loss: 0.4105
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 77.82%
# Train Loss: 0.4468
# Test Accuracy: 77.27%
# Test Loss: 0.4655
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 77.13%
# Train Loss: 0.5932
# Test Accuracy: 75.32%
# Test Loss: 0.6019
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 73.50%
# Train Loss: 0.6054
# Test Accuracy: 71.10%
# Test Loss: 0.6166
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 44.63%
# Train Loss: 0.6996
# Test Accuracy: 46.43%
# Test Loss: 0.6990
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 53.14%
# Train Loss: 0.6801
# Test Accuracy: 49.68%
# Test Loss: 0.6936
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 53.42%
# Train Loss: 0.6568
# Test Accuracy: 50.97%
# Test Loss: 0.6778
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 10 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 58.30%
# Train Loss: 0.6871
# Test Accuracy: 55.84%
# Test Loss: 0.6884
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 83.68%
# Train Loss: 1.7580
# Test Accuracy: 80.19%
# Test Loss: 2.4839
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 84.80%
# Train Loss: 0.3536
# Test Accuracy: 79.55%
# Test Loss: 0.4785
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3357
# Test Accuracy: 79.22%
# Test Loss: 0.4096
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3352
# Test Accuracy: 79.55%
# Test Loss: 0.4193
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3373
# Test Accuracy: 79.55%
# Test Loss: 0.4024
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3348
# Test Accuracy: 80.52%
# Test Loss: 0.4070
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3339
# Test Accuracy: 80.52%
# Test Loss: 0.4243
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3343
# Test Accuracy: 78.90%
# Test Loss: 0.4159
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3347
# Test Accuracy: 81.17%
# Test Loss: 0.4083
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3393
# Test Accuracy: 82.14%
# Test Loss: 0.4216
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 80.20%
# Train Loss: 0.4209
# Test Accuracy: 75.32%
# Test Loss: 0.4530
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 78.10%
# Train Loss: 0.5228
# Test Accuracy: 75.32%
# Test Loss: 0.5355
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 67.22%
# Train Loss: 0.6614
# Test Accuracy: 62.01%
# Test Loss: 0.6699
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 72.38%
# Train Loss: 0.6349
# Test Accuracy: 70.78%
# Test Loss: 0.6333
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 59.69%
# Train Loss: 0.6824
# Test Accuracy: 58.77%
# Test Loss: 0.6846
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 47.42%
# Train Loss: 0.6968
# Test Accuracy: 51.62%
# Test Loss: 0.6898
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3401
# Test Accuracy: 80.84%
# Test Loss: 0.4359
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3390
# Test Accuracy: 80.52%
# Test Loss: 0.4323
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3367
# Test Accuracy: 79.87%
# Test Loss: 0.4304
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3356
# Test Accuracy: 79.22%
# Test Loss: 0.4121
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3363
# Test Accuracy: 79.87%
# Test Loss: 0.4285
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4130
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3337
# Test Accuracy: 80.84%
# Test Loss: 0.4161
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3345
# Test Accuracy: 80.52%
# Test Loss: 0.4208
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3340
# Test Accuracy: 78.90%
# Test Loss: 0.4121
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3338
# Test Accuracy: 79.87%
# Test Loss: 0.4155
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 85.50%
# Train Loss: 0.3395
# Test Accuracy: 80.52%
# Test Loss: 0.4056
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 84.94%
# Train Loss: 0.3663
# Test Accuracy: 80.84%
# Test Loss: 0.4284
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 81.45%
# Train Loss: 0.4573
# Test Accuracy: 79.22%
# Test Loss: 0.4735
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 77.68%
# Train Loss: 0.5209
# Test Accuracy: 73.38%
# Test Loss: 0.5458
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 48.40%
# Train Loss: 0.6713
# Test Accuracy: 51.62%
# Test Loss: 0.6569
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 53.84%
# Train Loss: 0.6475
# Test Accuracy: 58.77%
# Test Loss: 0.6344
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3361
# Test Accuracy: 79.55%
# Test Loss: 0.4095
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 10.1025
# Test Accuracy: 80.19%
# Test Loss: 15.7933
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4174
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3345
# Test Accuracy: 80.84%
# Test Loss: 0.4211
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3353
# Test Accuracy: 79.87%
# Test Loss: 0.4189
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3339
# Test Accuracy: 80.52%
# Test Loss: 0.4129
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3338
# Test Accuracy: 79.87%
# Test Loss: 0.4191
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4152
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 87.45%
# Train Loss: 0.3338
# Test Accuracy: 81.17%
# Test Loss: 0.4149
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4167
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4141
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3346
# Test Accuracy: 80.19%
# Test Loss: 0.4135
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.22%
# Train Loss: 0.3542
# Test Accuracy: 82.79%
# Test Loss: 0.3790
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 80.75%
# Train Loss: 0.4485
# Test Accuracy: 77.27%
# Test Loss: 0.4728
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 81.31%
# Train Loss: 0.6018
# Test Accuracy: 79.55%
# Test Loss: 0.6066
#
# Training with 3 hidden layers, 8 neurons, ReLU activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 47.84%
# Train Loss: 0.6821
# Test Accuracy: 51.62%
# Test Loss: 0.6703
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3778
# Test Accuracy: 82.14%
# Test Loss: 0.4524
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3411
# Test Accuracy: 79.22%
# Test Loss: 0.4031
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 85.36%
# Train Loss: 0.3581
# Test Accuracy: 78.57%
# Test Loss: 0.4171
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3394
# Test Accuracy: 80.52%
# Test Loss: 0.4032
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3341
# Test Accuracy: 79.87%
# Test Loss: 0.4093
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3345
# Test Accuracy: 80.84%
# Test Loss: 0.4095
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3392
# Test Accuracy: 79.87%
# Test Loss: 0.4090
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3575
# Test Accuracy: 81.82%
# Test Loss: 0.4194
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 85.77%
# Train Loss: 0.3564
# Test Accuracy: 80.52%
# Test Loss: 0.4074
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 84.66%
# Train Loss: 0.4815
# Test Accuracy: 82.47%
# Test Loss: 0.4801
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 73.92%
# Train Loss: 0.6170
# Test Accuracy: 75.00%
# Test Loss: 0.6237
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 52.86%
# Train Loss: 0.6761
# Test Accuracy: 48.70%
# Test Loss: 0.6924
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 53.28%
# Train Loss: 0.6740
# Test Accuracy: 50.65%
# Test Loss: 0.6822
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 48.26%
# Train Loss: 0.6941
# Test Accuracy: 44.16%
# Test Loss: 0.6968
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 52.58%
# Train Loss: 0.7153
# Test Accuracy: 48.38%
# Test Loss: 0.7278
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 10 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 47.42%
# Train Loss: 0.7874
# Test Accuracy: 51.62%
# Test Loss: 0.7588
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 65.55%
# Train Loss: 0.6414
# Test Accuracy: 62.01%
# Test Loss: 0.7457
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3392
# Test Accuracy: 80.52%
# Test Loss: 0.4265
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3343
# Test Accuracy: 79.87%
# Test Loss: 0.4192
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3346
# Test Accuracy: 81.49%
# Test Loss: 0.4146
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3353
# Test Accuracy: 81.49%
# Test Loss: 0.4021
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 87.45%
# Train Loss: 0.3338
# Test Accuracy: 81.17%
# Test Loss: 0.4185
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4153
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3348
# Test Accuracy: 79.55%
# Test Loss: 0.4168
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3338
# Test Accuracy: 80.52%
# Test Loss: 0.4168
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3459
# Test Accuracy: 81.49%
# Test Loss: 0.4021
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 81.73%
# Train Loss: 0.4045
# Test Accuracy: 78.57%
# Test Loss: 0.4326
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 79.36%
# Train Loss: 0.4577
# Test Accuracy: 75.97%
# Test Loss: 0.4618
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 77.27%
# Train Loss: 0.5916
# Test Accuracy: 74.35%
# Test Loss: 0.6027
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 69.18%
# Train Loss: 0.6670
# Test Accuracy: 72.40%
# Test Loss: 0.6669
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 47.00%
# Train Loss: 0.7378
# Test Accuracy: 51.30%
# Test Loss: 0.7215
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 46.03%
# Train Loss: 0.7436
# Test Accuracy: 43.51%
# Test Loss: 0.7475
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3394
# Test Accuracy: 80.19%
# Test Loss: 0.4183
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3346
# Test Accuracy: 81.17%
# Test Loss: 0.4237
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3342
# Test Accuracy: 79.55%
# Test Loss: 0.4174
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3375
# Test Accuracy: 80.84%
# Test Loss: 0.4059
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3361
# Test Accuracy: 80.84%
# Test Loss: 0.4295
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3339
# Test Accuracy: 80.52%
# Test Loss: 0.4171
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3337
# Test Accuracy: 80.19%
# Test Loss: 0.4177
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4149
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4135
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3338
# Test Accuracy: 81.17%
# Test Loss: 0.4145
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3383
# Test Accuracy: 81.82%
# Test Loss: 0.4160
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 82.57%
# Train Loss: 0.4229
# Test Accuracy: 79.87%
# Test Loss: 0.4519
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 78.52%
# Train Loss: 0.5053
# Test Accuracy: 73.70%
# Test Loss: 0.5248
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 73.08%
# Train Loss: 0.6409
# Test Accuracy: 66.88%
# Test Loss: 0.6488
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 71.13%
# Train Loss: 0.6397
# Test Accuracy: 69.81%
# Test Loss: 0.6407
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 52.58%
# Train Loss: 0.6827
# Test Accuracy: 48.38%
# Test Loss: 0.6964
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3345
# Test Accuracy: 80.84%
# Test Loss: 0.4154
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3368
# Test Accuracy: 80.52%
# Test Loss: 0.4199
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3396
# Test Accuracy: 79.87%
# Test Loss: 0.4091
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3360
# Test Accuracy: 79.87%
# Test Loss: 0.4150
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3345
# Test Accuracy: 80.84%
# Test Loss: 0.4195
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4197
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4190
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3340
# Test Accuracy: 79.22%
# Test Loss: 0.4212
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3338
# Test Accuracy: 80.19%
# Test Loss: 0.4209
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4174
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4147
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3343
# Test Accuracy: 81.17%
# Test Loss: 0.4142
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3472
# Test Accuracy: 81.49%
# Test Loss: 0.4163
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 80.47%
# Train Loss: 0.4320
# Test Accuracy: 76.62%
# Test Loss: 0.4681
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 52.02%
# Train Loss: 0.6464
# Test Accuracy: 57.14%
# Test Loss: 0.6169
#
# Training with 3 hidden layers, 8 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 51.74%
# Train Loss: 0.6991
# Test Accuracy: 48.70%
# Test Loss: 0.7056
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 85.77%
# Train Loss: 0.3479
# Test Accuracy: 80.19%
# Test Loss: 0.4195
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3484
# Test Accuracy: 79.87%
# Test Loss: 0.4054
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3443
# Test Accuracy: 82.14%
# Test Loss: 0.4020
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3436
# Test Accuracy: 79.87%
# Test Loss: 0.4231
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 85.77%
# Train Loss: 0.3352
# Test Accuracy: 78.90%
# Test Loss: 0.4129
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3346
# Test Accuracy: 79.22%
# Test Loss: 0.4160
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3361
# Test Accuracy: 79.22%
# Test Loss: 0.4195
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 84.80%
# Train Loss: 0.3647
# Test Accuracy: 81.82%
# Test Loss: 0.4409
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 83.12%
# Train Loss: 0.3635
# Test Accuracy: 79.22%
# Test Loss: 0.4254
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 78.94%
# Train Loss: 0.5146
# Test Accuracy: 79.55%
# Test Loss: 0.5172
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 73.50%
# Train Loss: 0.6191
# Test Accuracy: 69.16%
# Test Loss: 0.6289
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 54.81%
# Train Loss: 0.6538
# Test Accuracy: 50.65%
# Test Loss: 0.6807
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 60.53%
# Train Loss: 0.6640
# Test Accuracy: 55.52%
# Test Loss: 0.6732
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 47.42%
# Train Loss: 0.6841
# Test Accuracy: 52.27%
# Test Loss: 0.6780
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 57.04%
# Train Loss: 0.6640
# Test Accuracy: 52.27%
# Test Loss: 0.6780
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 52.02%
# Train Loss: 0.7025
# Test Accuracy: 48.38%
# Test Loss: 0.7120
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.59%
# Train Loss: 0.3929
# Test Accuracy: 83.77%
# Test Loss: 0.4735
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3487
# Test Accuracy: 81.17%
# Test Loss: 0.4432
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3341
# Test Accuracy: 79.87%
# Test Loss: 0.4156
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3392
# Test Accuracy: 80.52%
# Test Loss: 0.4021
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3347
# Test Accuracy: 79.55%
# Test Loss: 0.4178
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3350
# Test Accuracy: 79.55%
# Test Loss: 0.4117
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3341
# Test Accuracy: 80.52%
# Test Loss: 0.4131
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3348
# Test Accuracy: 80.52%
# Test Loss: 0.4140
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3342
# Test Accuracy: 80.19%
# Test Loss: 0.4122
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3401
# Test Accuracy: 80.84%
# Test Loss: 0.4076
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 78.94%
# Train Loss: 0.4355
# Test Accuracy: 77.27%
# Test Loss: 0.4431
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 80.33%
# Train Loss: 0.5265
# Test Accuracy: 76.62%
# Test Loss: 0.5393
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 64.02%
# Train Loss: 0.6529
# Test Accuracy: 69.81%
# Test Loss: 0.6466
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 61.23%
# Train Loss: 0.6605
# Test Accuracy: 56.17%
# Test Loss: 0.6620
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 52.30%
# Train Loss: 0.7023
# Test Accuracy: 48.05%
# Test Loss: 0.7141
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 47.42%
# Train Loss: 0.6977
# Test Accuracy: 51.62%
# Test Loss: 0.6895
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3350
# Test Accuracy: 80.84%
# Test Loss: 0.4148
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3486
# Test Accuracy: 79.22%
# Test Loss: 0.4581
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3350
# Test Accuracy: 80.52%
# Test Loss: 0.4037
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3350
# Test Accuracy: 78.25%
# Test Loss: 0.4243
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3343
# Test Accuracy: 80.84%
# Test Loss: 0.4161
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3340
# Test Accuracy: 80.52%
# Test Loss: 0.4185
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3337
# Test Accuracy: 79.87%
# Test Loss: 0.4138
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3339
# Test Accuracy: 79.87%
# Test Loss: 0.4154
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3338
# Test Accuracy: 80.19%
# Test Loss: 0.4195
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4148
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 85.36%
# Train Loss: 0.3381
# Test Accuracy: 79.55%
# Test Loss: 0.3989
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 85.08%
# Train Loss: 0.3434
# Test Accuracy: 80.52%
# Test Loss: 0.4004
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 81.45%
# Train Loss: 0.4070
# Test Accuracy: 80.19%
# Test Loss: 0.4092
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 77.27%
# Train Loss: 0.6158
# Test Accuracy: 74.03%
# Test Loss: 0.6181
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 56.49%
# Train Loss: 0.6832
# Test Accuracy: 52.27%
# Test Loss: 0.6881
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 65.69%
# Train Loss: 0.6613
# Test Accuracy: 61.04%
# Test Loss: 0.6736
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3367
# Test Accuracy: 81.17%
# Test Loss: 0.4242
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 85.22%
# Train Loss: 14.1871
# Test Accuracy: 80.84%
# Test Loss: 17.0726
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3352
# Test Accuracy: 80.19%
# Test Loss: 0.4282
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3346
# Test Accuracy: 78.90%
# Test Loss: 0.4147
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3349
# Test Accuracy: 79.87%
# Test Loss: 0.4149
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3345
# Test Accuracy: 79.87%
# Test Loss: 0.4102
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4162
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3339
# Test Accuracy: 79.22%
# Test Loss: 0.4123
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4146
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4158
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4154
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3363
# Test Accuracy: 80.19%
# Test Loss: 0.4093
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.22%
# Train Loss: 0.3526
# Test Accuracy: 80.52%
# Test Loss: 0.3954
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 80.20%
# Train Loss: 0.4486
# Test Accuracy: 76.30%
# Test Loss: 0.4798
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 75.59%
# Train Loss: 0.5638
# Test Accuracy: 78.90%
# Test Loss: 0.5491
#
# Training with 3 hidden layers, 8 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 59.41%
# Train Loss: 0.6677
# Test Accuracy: 54.22%
# Test Loss: 0.6863
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3583
# Test Accuracy: 80.19%
# Test Loss: 0.4624
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3429
# Test Accuracy: 80.52%
# Test Loss: 0.4048
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 85.22%
# Train Loss: 0.3697
# Test Accuracy: 79.87%
# Test Loss: 0.4331
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 85.36%
# Train Loss: 0.3943
# Test Accuracy: 77.92%
# Test Loss: 0.5224
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 85.63%
# Train Loss: 0.3363
# Test Accuracy: 78.57%
# Test Loss: 0.4112
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3356
# Test Accuracy: 79.22%
# Test Loss: 0.4104
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3355
# Test Accuracy: 78.57%
# Test Loss: 0.4318
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 84.52%
# Train Loss: 0.3511
# Test Accuracy: 80.52%
# Test Loss: 0.4242
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3385
# Test Accuracy: 81.49%
# Test Loss: 0.4175
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 84.94%
# Train Loss: 0.3775
# Test Accuracy: 79.55%
# Test Loss: 0.4185
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 79.36%
# Train Loss: 0.5024
# Test Accuracy: 75.65%
# Test Loss: 0.5225
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 78.38%
# Train Loss: 0.5963
# Test Accuracy: 79.55%
# Test Loss: 0.5944
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 70.71%
# Train Loss: 0.6469
# Test Accuracy: 71.10%
# Test Loss: 0.6452
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 74.34%
# Train Loss: 0.6145
# Test Accuracy: 72.40%
# Test Loss: 0.6166
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 56.21%
# Train Loss: 0.6904
# Test Accuracy: 52.60%
# Test Loss: 0.6906
#
# Training with 3 hidden layers, 16 neurons, linear activation, 10 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 50.21%
# Train Loss: 0.6855
# Test Accuracy: 53.57%
# Test Loss: 0.6721
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 83.40%
# Train Loss: 0.3986
# Test Accuracy: 77.92%
# Test Loss: 0.4955
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 85.36%
# Train Loss: 0.3397
# Test Accuracy: 78.90%
# Test Loss: 0.4410
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 85.63%
# Train Loss: 0.3374
# Test Accuracy: 78.57%
# Test Loss: 0.4263
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 83.68%
# Train Loss: 0.8248
# Test Accuracy: 81.17%
# Test Loss: 1.0145
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3339
# Test Accuracy: 80.52%
# Test Loss: 0.4149
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3344
# Test Accuracy: 80.84%
# Test Loss: 0.4133
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3348
# Test Accuracy: 80.52%
# Test Loss: 0.4265
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3342
# Test Accuracy: 80.19%
# Test Loss: 0.4191
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3345
# Test Accuracy: 79.55%
# Test Loss: 0.4184
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3341
# Test Accuracy: 79.87%
# Test Loss: 0.4145
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3469
# Test Accuracy: 81.17%
# Test Loss: 0.4027
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 80.89%
# Train Loss: 0.4124
# Test Accuracy: 77.92%
# Test Loss: 0.4277
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 78.94%
# Train Loss: 0.5130
# Test Accuracy: 76.62%
# Test Loss: 0.5198
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 69.18%
# Train Loss: 0.6295
# Test Accuracy: 67.53%
# Test Loss: 0.6373
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 70.15%
# Train Loss: 0.6415
# Test Accuracy: 71.43%
# Test Loss: 0.6384
#
# Training with 3 hidden layers, 16 neurons, linear activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 53.97%
# Train Loss: 0.6831
# Test Accuracy: 50.97%
# Test Loss: 0.6789
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3489
# Test Accuracy: 81.17%
# Test Loss: 0.4460
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3412
# Test Accuracy: 79.22%
# Test Loss: 0.4422
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3346
# Test Accuracy: 80.52%
# Test Loss: 0.4133
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3384
# Test Accuracy: 79.87%
# Test Loss: 0.4323
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3346
# Test Accuracy: 80.84%
# Test Loss: 0.4125
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3354
# Test Accuracy: 80.52%
# Test Loss: 0.4211
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3336
# Test Accuracy: 80.19%
# Test Loss: 0.4145
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3342
# Test Accuracy: 78.90%
# Test Loss: 0.4130
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3338
# Test Accuracy: 80.19%
# Test Loss: 0.4200
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4145
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4141
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3371
# Test Accuracy: 81.49%
# Test Loss: 0.4069
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.63%
# Train Loss: 0.3525
# Test Accuracy: 80.52%
# Test Loss: 0.4175
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 82.01%
# Train Loss: 0.4662
# Test Accuracy: 77.27%
# Test Loss: 0.4787
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 76.85%
# Train Loss: 0.6079
# Test Accuracy: 74.03%
# Test Loss: 0.6168
#
# Training with 3 hidden layers, 16 neurons, linear activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 59.97%
# Train Loss: 0.6524
# Test Accuracy: 55.52%
# Test Loss: 0.6617
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3348
# Test Accuracy: 79.22%
# Test Loss: 0.4211
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3388
# Test Accuracy: 80.19%
# Test Loss: 0.4047
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4214
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3345
# Test Accuracy: 80.52%
# Test Loss: 0.4168
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3349
# Test Accuracy: 78.90%
# Test Loss: 0.4243
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3337
# Test Accuracy: 81.17%
# Test Loss: 0.4156
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4187
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3343
# Test Accuracy: 79.87%
# Test Loss: 0.4165
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3338
# Test Accuracy: 80.19%
# Test Loss: 0.4104
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4148
#
# Training with 3 hidden layers, 16 neurons, linear activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4173
#
# ...
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.91%
# Train Loss: 0.3354
# Test Accuracy: 80.84%
# Test Loss: 0.4034
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 85.50%
# Train Loss: 0.3538
# Test Accuracy: 80.52%
# Test Loss: 0.4078
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 75.87%
# Train Loss: 0.5265
# Test Accuracy: 77.60%
# Test Loss: 0.5156
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 74.20%
# Train Loss: 0.5708
# Test Accuracy: 73.38%
# Test Loss: 0.5757
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3396
# Test Accuracy: 82.14%
# Test Loss: 0.4009
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3348
# Test Accuracy: 79.87%
# Test Loss: 0.4243
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3346
# Test Accuracy: 80.52%
# Test Loss: 0.4136
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3422
# Test Accuracy: 80.52%
# Test Loss: 0.4286
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3357
# Test Accuracy: 79.87%
# Test Loss: 0.4275
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3343
# Test Accuracy: 80.52%
# Test Loss: 0.4219
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3339
# Test Accuracy: 80.52%
# Test Loss: 0.4144
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3342
# Test Accuracy: 79.87%
# Test Loss: 0.4212
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3344
# Test Accuracy: 79.87%
# Test Loss: 0.4097
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3337
# Test Accuracy: 79.87%
# Test Loss: 0.4173
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4162
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3340
# Test Accuracy: 80.52%
# Test Loss: 0.4139
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3340
# Test Accuracy: 80.84%
# Test Loss: 0.4088
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3363
# Test Accuracy: 82.79%
# Test Loss: 0.4041
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 84.10%
# Train Loss: 0.3692
# Test Accuracy: 80.84%
# Test Loss: 0.4034
#
# Training with 3 hidden layers, 32 neurons, Softmax activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 85.22%
# Train Loss: 0.3826
# Test Accuracy: 80.84%
# Test Loss: 0.4365
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3360
# Test Accuracy: 81.82%
# Test Loss: 0.4070
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 80.20%
# Train Loss: 0.4162
# Test Accuracy: 77.60%
# Test Loss: 0.4716
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 77.82%
# Train Loss: 1.0433
# Test Accuracy: 78.90%
# Test Loss: 1.0412
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 81.31%
# Train Loss: 2.2098
# Test Accuracy: 75.65%
# Test Loss: 2.9417
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3476
# Test Accuracy: 79.55%
# Test Loss: 0.4070
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3347
# Test Accuracy: 80.52%
# Test Loss: 0.4184
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3356
# Test Accuracy: 80.52%
# Test Loss: 0.4098
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3423
# Test Accuracy: 82.14%
# Test Loss: 0.4246
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3339
# Test Accuracy: 81.17%
# Test Loss: 0.4187
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3360
# Test Accuracy: 80.84%
# Test Loss: 0.4063
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 82.57%
# Train Loss: 0.3753
# Test Accuracy: 79.87%
# Test Loss: 0.4083
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 83.68%
# Train Loss: 0.4281
# Test Accuracy: 78.57%
# Test Loss: 0.4665
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 78.94%
# Train Loss: 0.5581
# Test Accuracy: 76.62%
# Test Loss: 0.5592
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 68.90%
# Train Loss: 0.6503
# Test Accuracy: 69.16%
# Test Loss: 0.6489
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 71.83%
# Train Loss: 0.6358
# Test Accuracy: 75.65%
# Test Loss: 0.6313
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 10 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 58.86%
# Train Loss: 0.6700
# Test Accuracy: 55.84%
# Test Loss: 0.6758
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.05%
# Train Loss: 0.3366
# Test Accuracy: 79.87%
# Test Loss: 0.4086
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 87.45%
# Train Loss: 0.3342
# Test Accuracy: 81.17%
# Test Loss: 0.4086
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 84.52%
# Train Loss: 0.3688
# Test Accuracy: 77.27%
# Test Loss: 0.4855
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 82.85%
# Train Loss: 2.1175
# Test Accuracy: 76.95%
# Test Loss: 2.8292
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3350
# Test Accuracy: 78.90%
# Test Loss: 0.4200
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3355
# Test Accuracy: 80.84%
# Test Loss: 0.4147
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3339
# Test Accuracy: 80.19%
# Test Loss: 0.4118
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3377
# Test Accuracy: 79.22%
# Test Loss: 0.4386
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3342
# Test Accuracy: 79.87%
# Test Loss: 0.4143
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3337
# Test Accuracy: 80.19%
# Test Loss: 0.4160
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3337
# Test Accuracy: 80.19%
# Test Loss: 0.4173
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 85.36%
# Train Loss: 0.3394
# Test Accuracy: 79.87%
# Test Loss: 0.4154
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.22%
# Train Loss: 0.3705
# Test Accuracy: 80.19%
# Test Loss: 0.4085
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 79.64%
# Train Loss: 0.4860
# Test Accuracy: 77.60%
# Test Loss: 0.4930
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 76.71%
# Train Loss: 0.5794
# Test Accuracy: 71.75%
# Test Loss: 0.5910
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 25 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 70.01%
# Train Loss: 0.6503
# Test Accuracy: 65.58%
# Test Loss: 0.6643
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3388
# Test Accuracy: 81.49%
# Test Loss: 0.4242
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 85.63%
# Train Loss: 0.3360
# Test Accuracy: 79.22%
# Test Loss: 0.4139
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3346
# Test Accuracy: 79.87%
# Test Loss: 0.4236
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 79.22%
# Train Loss: 0.6830
# Test Accuracy: 76.95%
# Test Loss: 0.8336
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3349
# Test Accuracy: 80.19%
# Test Loss: 0.4113
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3357
# Test Accuracy: 78.90%
# Test Loss: 0.4049
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3342
# Test Accuracy: 79.87%
# Test Loss: 0.4117
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3343
# Test Accuracy: 79.22%
# Test Loss: 0.4258
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 86.47%
# Train Loss: 0.3344
# Test Accuracy: 79.87%
# Test Loss: 0.4200
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4143
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4163
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3337
# Test Accuracy: 80.52%
# Test Loss: 0.4123
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 85.63%
# Train Loss: 0.3401
# Test Accuracy: 80.52%
# Test Loss: 0.4088
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 81.59%
# Train Loss: 0.3969
# Test Accuracy: 76.62%
# Test Loss: 0.4296
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 79.36%
# Train Loss: 0.5121
# Test Accuracy: 75.32%
# Test Loss: 0.5236
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 50 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 78.66%
# Train Loss: 0.5804
# Test Accuracy: 75.97%
# Test Loss: 0.5905
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 64 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3383
# Test Accuracy: 80.84%
# Test Loss: 0.4348
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 128 batch size
# Train Accuracy: 86.19%
# Train Loss: 0.3365
# Test Accuracy: 80.19%
# Test Loss: 0.4050
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 256 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3345
# Test Accuracy: 80.19%
# Test Loss: 0.4178
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.1 learning rate, 512 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3347
# Test Accuracy: 79.55%
# Test Loss: 0.4216
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 64 batch size
# Train Accuracy: 86.75%
# Train Loss: 0.3343
# Test Accuracy: 79.87%
# Test Loss: 0.4182
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 128 batch size
# Train Accuracy: 86.61%
# Train Loss: 0.3340
# Test Accuracy: 79.87%
# Test Loss: 0.4183
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3338
# Test Accuracy: 80.84%
# Test Loss: 0.4147
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.01 learning rate, 512 batch size
# Train Accuracy: 86.33%
# Train Loss: 0.3347
# Test Accuracy: 79.55%
# Test Loss: 0.4266
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 64 batch size
# Train Accuracy: 87.03%
# Train Loss: 0.3344
# Test Accuracy: 79.87%
# Test Loss: 0.4153
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 128 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4139
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 256 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3336
# Test Accuracy: 80.52%
# Test Loss: 0.4165
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.001 learning rate, 512 batch size
# Train Accuracy: 86.89%
# Train Loss: 0.3339
# Test Accuracy: 80.84%
# Test Loss: 0.4141
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 64 batch size
# Train Accuracy: 87.17%
# Train Loss: 0.3338
# Test Accuracy: 80.52%
# Test Loss: 0.4107
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 128 batch size
# Train Accuracy: 87.31%
# Train Loss: 0.3346
# Test Accuracy: 81.82%
# Test Loss: 0.4123
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 256 batch size
# Train Accuracy: 83.12%
# Train Loss: 0.3695
# Test Accuracy: 79.22%
# Test Loss: 0.4114
#
# Training with 3 hidden layers, 32 neurons, Tanh activation, 100 epochs, 0.0001 learning rate, 512 batch size
# Train Accuracy: 83.26%
# Train Loss: 0.4265
# Test Accuracy: 79.55%
# Test Loss: 0.4609
